# %% [markdown]
# <a href="https://colab.research.google.com/github/chrober24/SL1_2021/blob/main/ESRGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ESRGAN

# %%
# !git clone https://github.com/xinntao/ESRGAN
# %cd ESRGAN
# %cd models
# !gdown --id 1pJ_T-V1dpb1ewoEra1TGSWl5e6H7M4NN
# !gdown --id 1TPrz5QKd8DHHt1k8SRtm6tMiPjz_Qene
# !gdown --id 1mSJ6Z40weL-dnPvi390xDd3uZBCFMeqr
# !gdown --id 1MJFgqXJrMkPdKtiuy7C6xfsU1QIbXEb-
# %cd ../
# Out:
# Cloning into 'ESRGAN'...
# remote: Enumerating objects: 210, done.
# remote: Total 210 (delta 0), reused 0 (delta 0), pack-reused 210
# Receiving objects: 100% (210/210), 24.85 MiB | 6.80 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/ESRGAN
# /content/ESRGAN/models
# Downloading...
# From: https://drive.google.com/uc?id=1pJ_T-V1dpb1ewoEra1TGSWl5e6H7M4NN
# To: /content/ESRGAN/models/RRDB_PSNR_x4.pth
# 66.9MB [00:00, 182MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TPrz5QKd8DHHt1k8SRtm6tMiPjz_Qene
# To: /content/ESRGAN/models/RRDB_ESRGAN_x4.pth
# 66.9MB [00:01, 52.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1mSJ6Z40weL-dnPvi390xDd3uZBCFMeqr
# To: /content/ESRGAN/models/RRDB_PSNR_x4_old_arch.pth
# 67.0MB [00:01, 42.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MJFgqXJrMkPdKtiuy7C6xfsU1QIbXEb-
# To: /content/ESRGAN/models/RRDB_ESRGAN_x4_old_arch.pth
# 67.0MB [00:02, 30.2MB/s]
# /content/ESRGAN

# %%
#cleanup folder defaults
# !rm /content/ESRGAN/results/baboon_ESRGAN.png
# !rm /content/ESRGAN/LR/*.png

# %% [markdown]
# Add the images you want to superres to the `LR` folder inside `ESRGAN`. Then run the next cell.

# %%
# !python test.py
# Out:
# Model path models/RRDB_ESRGAN_x4.pth.
# Testing...
# 1 04206
# 2 04211
# 3 04212
# 4 04245
# 5 04237
# 6 04239
# 7 04209
# 8 04228
# 9 04205
# 10 04221
# 11 04229
# 12 04207
# 13 04231
# 14 04220
# 15 04243
# 16 04246
# 17 04238
# 18 04240
# 19 04242
# 20 04226
# 21 04234
# 22 04248
# 23 04247
# 24 04241
# 25 04232
# 26 04210
# 27 04215
# 28 04219
# 29 04225
# 30 04227
# 31 04222
# 32 04216
# 33 04233
# 34 04224
# 35 04236
# 36 04230
# 37 04223
# 38 04244
# 39 04213
# 40 04217
# 41 04214
# 42 04235
# 43 04218
# 44 04208

# %% [markdown]
# Let’s zip the results folder and then download it.

# %%
# !zip -r results.zip /content/ESRGAN/results
# Out:
#   adding: content/ESRGAN/results/ (stored 0%)
#   adding: content/ESRGAN/results/04207_rlt.png (deflated 2%)
#   adding: content/ESRGAN/results/04234_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04205_rlt.png (deflated 1%)
#   adding: content/ESRGAN/results/04245_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04239_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04225_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04227_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04223_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04238_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04214_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04226_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04241_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04248_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/04228_rlt.png (deflated 0%)
#   adding: content/ESRGAN/results/.ipynb_checkpoints/ (stored 0%)
# ...
